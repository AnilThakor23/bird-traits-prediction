# %%
import pandas as pd
from pathlib import Path

BASE = Path("../data/raw")

# better table display
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 1200)
pd.set_option("display.max_colwidth", 100)

# warning fix (mixed types)
import warnings
warnings.filterwarnings("ignore")

# %%
df_raw = pd.read_csv(BASE / "core/AVONET_Raw_Data.csv", encoding="latin1")

print("Shape:", df_raw.shape , "\n")
print("Columns:", list(df_raw.columns) , "\n")
df_raw.head()
# Out:
# Shape: (90371, 204)
#
# ...

# %%
df_bl = pd.read_csv(BASE / "core/AVONET1_BirdLife.csv", encoding="latin1")

print("Shape:", df_bl.shape , "\n")
print("Columns:", list(df_bl.columns), "\n")
df_bl.head()
# Out:
# Shape: (11009, 37)
#
# Columns: ['Sequence', 'Species1', 'Family1', 'Order1', 'Avibase.ID1', 'Total.individuals', 'Female', 'Male', 'Unknown', 'Complete.measures', 'Beak.Length_Culmen', 'Beak.Length_Nares', 'Beak.Width', 'Beak.Depth', 'Tarsus.Length', 'Wing.Length', 'Kipps.Distance', 'Secondary1', 'Hand-Wing.Index', 'Tail.Length', 'Mass', 'Mass.Source', 'Mass.Refs.Other', 'Inference', 'Traits.inferred', 'Reference.species', 'Habitat', 'Habitat.Density', 'Migration', 'Trophic.Level', 'Trophic.Niche', 'Primary.Lifestyle', 'Min.Latitude', 'Max.Latitude', 'Centroid.Latitude', 'Centroid.Longitude', 'Range.Size']
# ...

# %%
df_ebird = pd.read_excel(
    BASE / "core/AVONET2_eBird.xlsx", sheet_name=1 , header=0
)

print("Shape:", df_ebird.shape, "\n")
print("Columns:", list(df_ebird.columns), "\n")
df_ebird.head()
# Out:
# Shape: (10661, 31)
#
# Columns: ['Species2', 'Family2', 'Order2', 'Avibase.ID2', 'Total.individuals', 'Female', 'Male', 'Unknown', 'Complete.measures', 'Beak.Length_Culmen', 'Beak.Length_Nares', 'Beak.Width', 'Beak.Depth', 'Tarsus.Length', 'Wing.Length', 'Kipps.Distance', 'Secondary1', 'Hand-Wing.Index', 'Tail.Length', 'Mass', 'Mass.Source', 'Mass.Refs.Other', 'Inference', 'Traits.inferred', 'Reference.species', 'Habitat', 'Habitat.Density', 'Migration', 'Trophic.Level', 'Trophic.Niche', 'Primary.Lifestyle']
#                 Species2       Family2           Order2       Avibase.ID2  Total.individuals  Female  Male  Unknown  Complete.measures  Beak.Length_Culmen  Beak.Length_Nares  Beak.Width  Beak.Depth  Tarsus.Length  Wing.Length  Kipps.Distance  Secondary1  Hand-Wing.Index  Tail.Length   Mass Mass.Source Mass.Refs.Other Inference Traits.inferred Reference.species    Habitat  Habitat.Density  Migration Trophic.Level Trophic.Niche Primary.Lifestyle
# ...

# %%
df_birdtree = pd.read_excel( BASE / "core/AVONET3_BirdTree.xlsx", sheet_name=1 , header=0 )

print("Shape:", df_birdtree.shape, "\n")
print("Columns:", list(df_birdtree.columns), "\n")
df_birdtree.head()
# Out:
# Shape: (9993, 36)
#
# Columns: ['Species3', 'Family3', 'Order3', 'Total.individuals', 'Female', 'Male', 'Unknown', 'Complete.measures', 'Beak.Length_Culmen', 'Beak.Length_Nares', 'Beak.Width', 'Beak.Depth', 'Tarsus.Length', 'Wing.Length', 'Kipps.Distance', 'Secondary1', 'Hand-Wing.Index', 'Tail.Length', 'Mass', 'Mass.Source', 'Mass.Refs.Other', 'Inference', 'Traits.inferred', 'Reference.species', 'Habitat', 'Habitat.Density', 'Migration', 'Trophic.Level', 'Trophic.Niche', 'Primary.Lifestyle', 'Min.Latitude', 'Max.Latitude', 'Centroid.Latitude', 'Centroid.Longitude', 'Range.Size', 'Species.Status']
# ...

# %%
df_cross = pd.read_csv( BASE / "metadata/BirdLife_BirdTree_Taxonomy_Relation.csv", encoding="latin1" )

print("Shape:", df_cross.shape , "\n")
print("Columns:", list(df_cross.columns), "\n")
df_cross.head()
# Out:
# Shape: (11291, 4)
#
# Columns: ['Species1', 'Species3', 'Match.type', 'Match.notes']
#                    Species1                  Species3  Match.type Match.notes
# 0         Abeillia abeillei         Abeillia abeillei  1BL to 1BT         NaN
# 1    Abroscopus albogularis    Abroscopus albogularis  1BL to 1BT         NaN
# 2    Abroscopus schisticeps    Abroscopus schisticeps  1BL to 1BT         NaN
# 3  Abroscopus superciliaris  Abroscopus superciliaris  1BL to 1BT         NaN
# 4            Aburria aburri            Aburria aburri  1BL to 1BT         NaN

# %%
df_family = pd.read_csv( BASE / "metadata/Family_Specimen_Stats.csv",encoding="latin1" )

print("Shape:", df_family.shape, "\n")
print("Columns:", list(df_family.columns), "\n")
df_family.head()
# Out:
# Shape: (243, 10)
#
# Columns: ['Unnamed: 0', 'familyIDS', 'Number_of_species_per_family', 'Average_number_of_specimens_per_family', 'Average_number_of_complete_specimens_per_family', 'Portion_of_family_with_at_least_one_full_specimen', 'Portion_of_complete_specimens_per_family', 'Portion_of_family_with_at_least_four_specimens', 'Portion_of_family_with_at_least_four_full_traits_measured_per_species', 'Portion_of_family_with_at_least_four_main_traits_measured_per_species']
#    Unnamed: 0      familyIDS  Number_of_species_per_family  Average_number_of_specimens_per_family  Average_number_of_complete_specimens_per_family  Portion_of_family_with_at_least_one_full_specimen  Portion_of_complete_specimens_per_family  Portion_of_family_with_at_least_four_specimens  Portion_of_family_with_at_least_four_full_traits_measured_per_species  Portion_of_family_with_at_least_four_main_traits_measured_per_species
# ...

# %%
df_source = pd.read_csv( BASE / "metadata/Source_Details.csv", encoding="latin1" )

print("Shape:", df_source.shape, "\n")
print("Columns:", list(df_source.columns), "\n")
df_source.head()
# Out:
# Shape: (83, 8)
#
# Columns: ['Source', 'Institution.name', 'Specimens.sampled', 'Institution.city', 'Institution.country', 'Latitude', 'Longitude', 'Address']
#   Source                                      Institution.name  Specimens.sampled Institution.city Institution.country   Latitude  Longitude                                                               Address
# 0  NHMUK                                Natural History Museum            46060.0           London                  UK  51.496715  -0.176367                           Cromwell Rd, Kensington, London SW7 5BD, UK
# 1   AMNH                    American Museum of Natural History             5769.0         New York                 USA  40.782045 -73.971711                  Central Park West & 79th St, New York, NY 10024, USA
# ...

# %%
df_history = pd.read_csv( BASE / "metadata/Trait_Database_History.csv", encoding="latin1" )

print("Shape:", df_history.shape, "\n")
print("Columns:", list(df_history.columns), "\n")
df_history.head()
# Out:
# Shape: (21, 6)
#
# Columns: ['Year', 'Reference', 'openSource', 'NumSpecies', 'NumSpecimen', 'NumMorphTraits']
#    Year                               Reference  openSource  NumSpecies  NumSpecimen  NumMorphTraits
# 0  1961      Hartman 1961 Smithsonian Misc Coll           1         360         2160               4
# 1  1977                    Ricklefs 1977 Condor           0          82          460               8
# 2  1982             James 1982 Ann Zool Fennici           0         680         1360               8
# 3  1987  Miles, Ricklefs and Travis 1987 Am Nat           0          38          190               8
# 4  1991            Leisler & Winkler 1991 J Orn           0          47         1000              25
